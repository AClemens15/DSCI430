# %%
import pandas as pd

# %% [markdown]
# Part 1
# - read files in as csv and head for a single file

# %%
year = 2002
df1= pd.read_csv("C:\\Users\\kg4665cm\\Desktop\\DSCI430\lakes\\MinneMUDAC_raw_files\\" + "{0}_metro_tax_parcels.txt".format(year), sep="|", chunksize=500)

# %%
from toolz import first
firstchunk= first(df1)
firstchunk.head()
# Out:
#    ACRES_DEED  ACRES_POLY  AGPRE_ENRD  AGPRE_EXPD  AG_PRESERV  BASEMENT  \
# 0         NaN         NaN         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN         NaN         NaN       NaN
# 2         NaN         NaN         NaN         NaN         NaN       NaN
# 3         NaN         NaN         NaN         NaN         NaN       NaN
# 4         NaN         NaN         NaN         NaN         NaN       NaN
#
#    BLDG_NUM  BLOCK     CITY  CITY_USPS  ...  XUSE1_DESC  XUSE2_DESC  \
# 0   14195.0    NaN  ANDOVER        NaN  ...         NaN         NaN
# 1   14189.0    NaN  ANDOVER        NaN  ...         NaN         NaN
# 2   14177.0    NaN  ANDOVER        NaN  ...         NaN         NaN
# 3   14165.0    NaN  ANDOVER        NaN  ...         NaN         NaN
# 4   14159.0    NaN  ANDOVER        NaN  ...         NaN         NaN
#
#    XUSE3_DESC  XUSE4_DESC  YEAR_BUILT  Year      ZIP  ZIP4  centroid_lat  \
# ...

# %%
columns_ = firstchunk.columns
columns_
# Out:
# Index(['ACRES_DEED', 'ACRES_POLY', 'AGPRE_ENRD', 'AGPRE_EXPD', 'AG_PRESERV',
#        'BASEMENT', 'BLDG_NUM', 'BLOCK', 'CITY', 'CITY_USPS', 'COOLING',
#        'COUNTY_ID', 'DWELL_TYPE', 'EMV_BLDG', 'EMV_LAND', 'EMV_TOTAL',
#        'FIN_SQ_FT', 'GARAGE', 'GARAGESQFT', 'GREEN_ACRE', 'HEATING',
#        'HOMESTEAD', 'HOME_STYLE', 'LANDMARK', 'LOT', 'MULTI_USES', 'NUM_UNITS',
#        'OPEN_SPACE', 'OWNER_MORE', 'OWNER_NAME', 'OWN_ADD_L1', 'OWN_ADD_L2',
#        'OWN_ADD_L3', 'OWN_NAME', 'PARC_CODE', 'PIN', 'PIN_1', 'PLAT_NAME',
#        'PREFIXTYPE', 'PREFIX_DIR', 'SALE_DATE', 'SALE_VALUE', 'SCHOOL_DST',
#        'SPEC_ASSES', 'STREET', 'STREETNAME', 'STREETTYPE', 'STRUC_TYPE',
#        'SUFFIX_DIR', 'Shape_Area', 'Shape_Leng', 'TAX_ADD_L1', 'TAX_ADD_L2',
#        'TAX_ADD_L3', 'TAX_ADD_LI', 'TAX_CAPAC', 'TAX_EXEMPT', 'TAX_NAME',
#        'TOTAL_TAX', 'UNIT_INFO', 'USE1_DESC', 'USE2_DESC', 'USE3_DESC',
#        'USE4_DESC', 'WSHD_DIST', 'XUSE1_DESC', 'XUSE2_DESC', 'XUSE3_DESC',
# ...

# %%
columnsset = set(columns_)
columnsset
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'PIN_1',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREET',
#  'STREETNAME',
#  'STREETTYPE',
#  'STRUC_TYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_ADD_LI',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
# ...

# %% [markdown]
# Part 2
# - make a list comprehension to get column names for each file

# %%
df2 = [pd.read_csv("C:\\Users\\kg4665cm\\Desktop\\DSCI430\\lakes\\MinneMUDAC_raw_files\\" + "{0}_metro_tax_parcels.txt".format(year), sep="|", chunksize=500) for text in range(2002,2016)]
df2

# %%
firstchunks = [first(chunk) for chunk in df2]
firstchunks[0]
# Out:
#      ACRES_DEED  ACRES_POLY  AGPRE_ENRD  AGPRE_EXPD  AG_PRESERV  BASEMENT  \
# 0           NaN         NaN         NaN         NaN         NaN       NaN
# 1           NaN         NaN         NaN         NaN         NaN       NaN
# 2           NaN         NaN         NaN         NaN         NaN       NaN
# 3           NaN         NaN         NaN         NaN         NaN       NaN
# 4           NaN         NaN         NaN         NaN         NaN       NaN
# 5           NaN         NaN         NaN         NaN         NaN       NaN
# 6           NaN         NaN         NaN         NaN         NaN       NaN
# 7           NaN         NaN         NaN         NaN         NaN       NaN
# 8           NaN         NaN         NaN         NaN         NaN       NaN
# 9           NaN         NaN         NaN         NaN         NaN       NaN
# 10          NaN         NaN         NaN         NaN         NaN       NaN
# 11          NaN         NaN         NaN         NaN         NaN       NaN
# ...

# %%
firstcolumns=  [column.columns for column in firstchunks]
firstcolumns[0]
# Out:
# Index(['ACRES_DEED', 'ACRES_POLY', 'AGPRE_ENRD', 'AGPRE_EXPD', 'AG_PRESERV',
#        'BASEMENT', 'BLDG_NUM', 'BLOCK', 'CITY', 'CITY_USPS', 'COOLING',
#        'COUNTY_ID', 'DWELL_TYPE', 'EMV_BLDG', 'EMV_LAND', 'EMV_TOTAL',
#        'FIN_SQ_FT', 'GARAGE', 'GARAGESQFT', 'GREEN_ACRE', 'HEATING',
#        'HOMESTEAD', 'HOME_STYLE', 'LANDMARK', 'LOT', 'MULTI_USES', 'NUM_UNITS',
#        'OPEN_SPACE', 'OWNER_MORE', 'OWNER_NAME', 'OWN_ADD_L1', 'OWN_ADD_L2',
#        'OWN_ADD_L3', 'OWN_NAME', 'PARC_CODE', 'PIN', 'PIN_1', 'PLAT_NAME',
#        'PREFIXTYPE', 'PREFIX_DIR', 'SALE_DATE', 'SALE_VALUE', 'SCHOOL_DST',
#        'SPEC_ASSES', 'STREET', 'STREETNAME', 'STREETTYPE', 'STRUC_TYPE',
#        'SUFFIX_DIR', 'Shape_Area', 'Shape_Leng', 'TAX_ADD_L1', 'TAX_ADD_L2',
#        'TAX_ADD_L3', 'TAX_ADD_LI', 'TAX_CAPAC', 'TAX_EXEMPT', 'TAX_NAME',
#        'TOTAL_TAX', 'UNIT_INFO', 'USE1_DESC', 'USE2_DESC', 'USE3_DESC',
#        'USE4_DESC', 'WSHD_DIST', 'XUSE1_DESC', 'XUSE2_DESC', 'XUSE3_DESC',
# ...

# %%
columnssets = [set(set_) for set_ in firstcolumns]
columnssets[0]
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'PIN_1',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREET',
#  'STREETNAME',
#  'STREETTYPE',
#  'STRUC_TYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_ADD_LI',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
# ...

# %% [markdown]
# Part 6
# - make a list of column name sets, one for each file

# %% [markdown]
# Part 7
# - make a list of common column names

# %%
all_items = columnssets[0]
for columns in columnssets[1:]:
    all_items = all_items.union(columns)
all_items
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'PIN_1',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREET',
#  'STREETNAME',
#  'STREETTYPE',
#  'STRUC_TYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_ADD_LI',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
# ...

# %%
common_items = all_items
for columns in columnssets[1:]:
    common_items = common_items.intersection(columns)
common_items
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'PIN_1',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREET',
#  'STREETNAME',
#  'STREETTYPE',
#  'STRUC_TYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_ADD_LI',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
# ...

# %% [markdown]
# Part 8
# - determine what files have extra column names

# %%
totals = [(year, columns.difference(common_items)) for year, columns in zip(range(2002,2016), columnssets)]
totals
# Out:
# [(2002, set()),
#  (2003, set()),
#  (2004, set()),
#  (2005, set()),
#  (2006, set()),
#  (2007, set()),
#  (2008, set()),
#  (2009, set()),
#  (2010, set()),
#  (2011, set()),
#  (2012, set()),
#  (2013, set()),
#  (2014, set()),
#  (2015, set())]
